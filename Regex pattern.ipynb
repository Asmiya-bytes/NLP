# %% [markdown]
# <a href="https://colab.research.google.com/github/Asmiya-bytes/NLP/blob/main/Regex%20pattern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

def detect_word_pattern(pattern, text):
    matches = re.findall(pattern, text)
    if matches:
        print("Word patterns detected")
        for match in matches:
            print(match)
    else:
        print("No word detected")

# Sample inputs
sample_inputs = [
    (r"\bcat\b", "The cat sat on the mat"),
    (r"\b\d{4}\b", "The year is 2026 and last year was 2025"),
    (r"\b[a-zA-Z]{5}\b", "Hello world from python"),
    (r"\b\w+ing\b", "Running and walking are good exercises")
]

for pattern, text in sample_inputs:
    print("Pattern:", pattern)
    print("Text:", text)
    detect_word_pattern(pattern, text)
    print("-" * 40)
# Out:
# Pattern: \bcat\b
# Text: The cat sat on the mat
# Word patterns detected
# cat
# ----------------------------------------
# Pattern: \b\d{4}\b
# Text: The year is 2026 and last year was 2025
# Word patterns detected
# 2026
# 2025
# ----------------------------------------
# Pattern: \b[a-zA-Z]{5}\b
# Text: Hello world from python
# Word patterns detected
# Hello
# world
# ----------------------------------------
# Pattern: \b\w+ing\b
# Text: Running and walking are good exercises
# Word patterns detected
# Running
# walking
# ----------------------------------------
