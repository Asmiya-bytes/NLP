# %% [markdown]
# <a href="https://colab.research.google.com/github/Asmiya-bytes/NLP/blob/main/tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def tokenize_text(text):
    tokens = text.split()
    return tokens

if __name__ == "__main__":
    text = "Natural Language Processing is fun"

    tokens = tokenize_text(text)

    print("Tokens:")
    print(tokens)
# Out:
# Tokens:
# ['Natural', 'Language', 'Processing', 'is', 'fun']
